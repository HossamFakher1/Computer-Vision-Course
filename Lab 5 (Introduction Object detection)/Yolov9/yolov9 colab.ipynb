# %%
#https://universe.roboflow.com/inteligencia-artificial-proyecto-final-0qzli/piedra-papel-o-tijeras/dataset/6#
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AE4x6F2UzA8PofP1XkmV")
project = rf.workspace("inteligencia-artificial-proyecto-final-0qzli").project("piedra-papel-o-tijeras")
version = project.version(6)
dataset = version.download("yolov9")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 931.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.32 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.2/78.2 GB disk)

# %%
# Build a YOLOv9c model from scratch and train it on the COCO8 example dataset for 10 epochs
# !yolo task=detect  mode=train data=/content/PRS/data.yaml model=/content/runs/detect/train2/weights/best.pt epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.1.32 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image, display

# %%
display(Image(filename=f"/content/runs/detect/train2/results.png", width=1000))

# %%
display(Image(filename=f"/content/runs/detect/train2/confusion_matrix.png", width=1000))

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt imgsz=640 conf=0.5 \
source=/content/PRS/test/images
# Out:
# Ultralytics YOLOv8.1.32 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv9c summary (fused): 384 layers, 25321561 parameters, 0 gradients, 102.3 GFLOPs
#
# image 1/50 /content/PRS/test/images/Imagen-de-WhatsApp-2023-11-22-a-las-22-56-12_057bf138_jpg.rf.2494a8f698e66ecc1aad8691ca41ee90.jpg: 640x640 (no detections), 49.7ms
# image 2/50 /content/PRS/test/images/Imagen-de-WhatsApp-2023-11-23-a-las-12-09-38_5ce93301_jpg.rf.37db3622b5f0bfbe8529781690b45d3a.jpg: 640x640 (no detections), 44.3ms
# image 3/50 /content/PRS/test/images/Imagen-de-WhatsApp-2023-11-23-a-las-12-09-40_0afe4a06_jpg.rf.31db1685fe1979a0c4547a622ee0424e.jpg: 640x640 (no detections), 41.0ms
# image 4/50 /content/PRS/test/images/Imagen-de-WhatsApp-2023-11-23-a-las-12-46-17_6ff77ce7_jpg.rf.8488d05a7b997a05addc3f37f9e6a0e1.jpg: 640x640 (no detections), 41.1ms
# ...

# %%
# Display inference on ALL test images
import glob
from IPython.display import Image, display


for imageName in glob.glob("/kaggle/working/runs/detect/predict/*.jpg")[2:6] :#assuming JPG
    print("\n")
    display(Image(filename=imageName))
